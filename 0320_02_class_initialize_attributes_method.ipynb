# %% [markdown]
# <a href="https://colab.research.google.com/github/canlasnicole/Application_Programming-/blob/main/0320_02_class_initialize_attributes_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color='blue'> Class = Chef**
# > ### **Understanding Class와 속성, 인스터스**

# %% [markdown]
# ## **과제 1. faker를 사용하여 1000명의 데이터를 class를 이용하여 만들어라**
#
# - [click faker](https://faker.readthedocs.io/en/master/)

# %% [markdown]
# ## **과제 2. Tom이 Jerry를 쫒아가는 행위를 method(함수)로 만들어 보자(10번 following)**
#
# ### **class User:**
# > **def __init __ (self):**
# >   - ##### Initialize attributes
# >   - **HAS (Attiributes)**
#
# > **def following_mode():**
# >   - ##### change attributes (following, follower) for chasing
# >   - **Does (Method, Change the attributes)**
#
# <img src= 'https://pbs.twimg.com/profile_images/810136393/tom-jerry-pic_400x400.jpg' width=300>

# %%
# !pip install faker

import pandas as pd
from faker import Faker
import random

fake = Faker()

class User:
    def __init__(self):
        self.name = fake.name()
        self.age = random.randint(20, 60)
        self.address = fake.address().replace("\n", " ")
        self.phone = fake.phone_number()
        self.job = fake.job()
        self.follow_count = 0

    def following_mode(self, target_name):
        self.follow_count += 1
        print(f" {self.name} is chasing {target_name}! (Attempt {self.follow_count}/10)")


user_objects = [User() for _ in range(1000)]
data_for_pandas = [vars(u) for u in user_objects]

df = pd.DataFrame(data_for_pandas)

df_final = df[['name', 'age', 'address', 'phone', 'job']]

print("# Task 1: First 5 rows of the 1,000 users DataFrame ")
display(df_final.head())
print(f"\nTotal rows generated: {len(df_final)}")
print("-" * 50)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 40.3 MB/s eta 0:00:00
# ...
# # Task 1: First 5 rows of the 1,000 users DataFrame
#              name  age                                            address  \
# 0     Mary Howell   56              238 Reyes Spur New Samantha, NE 09862
# 1      Mary Reese   37            1074 Guzman Island Lake Kevin, OH 00671
# 2  Anthony Warren   56             1400 Welch Street Deannaside, CO 62143
# 3   Diane Wallace   48    2860 Jean Mission West Stephanieville, KY 18250
# 4   Jeffrey Perry   30  292 Timothy Rue Suite 518 Mcdowellshire, GU 02158
#
#                    phone                      job
# 0             5423741269           Pilot, airline
# 1           784-611-0227        Financial manager
# 2  +1-215-786-3406x73524      Mechanical engineer
# 3       370-363-3468x733  Data processing manager
# 4       754.644.2085x635                     Copy
# Total rows generated: 1000
# --------------------------------------------------

# %%
class User:
    def __init__(self, name):
        self.name = name
        self.following = 0
        self.follower = 0

    def following_mode(self, other_user):
        self.following += 1
        other_user.follower += 1
        print(f" {self.name} is chasing {other_user.name}!")

print(" Task 2: Tom chasing Jerry logic ")

tom = User("Tom")
jerry = User("Jerry")

for _ in range(10):
    tom.following_mode(jerry)

print(f"\n{tom.name} following: {tom.following}")
print(f"{jerry.name} follower: {jerry.follower}")
# Out:
#  Task 2: Tom chasing Jerry logic
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#  Tom is chasing Jerry!
#
# Tom following: 10
# Jerry follower: 10
